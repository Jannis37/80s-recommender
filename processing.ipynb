# %% [markdown]
# # Processing
#
# In this notebook the queried data from the spotify API is processed into an according format.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel, polynomial_kernel, sigmoid_kernel, rbf_kernel, laplacian_kernel, chi2_kernel, euclidean_distances, manhattan_distances

# %% [markdown]
# ## General overview

# %%
#df = pd.read_csv('data/DE/data-neu.csv')
df = pd.read_csv('data/data_with_country.csv')

# %%
df.head()
# Out:
#                           name         artists                       album  \
# 0   That's No Way To Get Along  Robert Wilkins  The Original Rolling Stone
# 1              I Got A Problem  Albert Collins                   Frostbite
# 2  The Highway Is Like A Woman  Albert Collins                   Frostbite
# 3                Alabama Blues  Robert Wilkins  The Original Rolling Stone
# 4               Get Away Blues  Robert Wilkins  The Original Rolling Stone
#
#   release_date release_date_precision  chart_power              spotify_id  \
# 0   1980-01-01                    day          NaN  5JKdsNzhJGpoaKBFZpOKQ3
# 1   1980-02-05                    day          NaN  6e2PhVePvqe7w4VNBTslef
# 2   1980-02-05                    day          NaN  4Qzcy6jU0yeck7IuCqGWSi
# 3   1980-01-01                    day          NaN  42zUiYaKltE7jFWb57fXAW
# 4   1980-01-01                    day          NaN  0hCrfp9WImVO6KWI30O1sM
#
#                                     uri  popularity  danceability  ...  \
# 0  spotify:track:5JKdsNzhJGpoaKBFZpOKQ3          22         0.427  ...
# 1  spotify:track:6e2PhVePvqe7w4VNBTslef          15         0.760  ...
# 2  spotify:track:4Qzcy6jU0yeck7IuCqGWSi          16         0.751  ...
# 3  spotify:track:42zUiYaKltE7jFWb57fXAW          11         0.490  ...
# 4  spotify:track:0hCrfp9WImVO6KWI30O1sM           4         0.629  ...
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0407         0.980           0.00000    0.1920    0.381   97.078
# 1       0.0573         0.328           0.03570    0.0447    0.849  102.183
# 2       0.0361         0.419           0.11000    0.1050    0.771   98.545
# 3       0.0716         0.972           0.00000    0.1590    0.905  205.718
# 4       0.0431         0.968           0.00238    0.0941    0.322  119.752
#
#    duration_ms  time_signature          isrc    genres
# 0       173827               4  USA370640304  acoustic
# 1       274707               4  USARL8071903  acoustic
# 2       302600               4  USARL8071904  acoustic
# 3       157933               3  USA370640301  acoustic
# 4       213107               4  USA370640300  acoustic
#
# [5 rows x 24 columns]

# %%
df['genres'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'bluegrass', 'blues', 'brazil', 'british', 'cantopop',
#        'chicago-house', 'children', 'chill', 'classical', 'club',
#        'comedy', 'country', 'dance', 'dancehall', 'disco', 'dub',
#        'dubstep', 'edm', 'electro', 'electronic', 'folk', 'forro',
#        'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'groove',
#        'grunge', 'guitar', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'indian', 'indie',
#        'indie-pop', 'industrial', 'j-dance', 'j-idol', 'j-pop', 'j-rock',
#        'jazz', 'k-pop', 'latin', 'latino', 'malay', 'mandopop', 'metal',
#        'minimal-techno', 'mpb', 'new-age', 'opera', 'pagode', 'party',
#        'piano', 'pop', 'pop-film', 'power-pop', 'progressive-house',
#        'psych-rock', 'punk', 'punk-rock', 'r-n-b', 'reggae', 'reggaeton',
#        'rock', 'rock-n-roll', 'rockabilly', 'salsa', 'samba', 'sertanejo',
#        'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul',
#        'spanish', 'swedish', 'synth-pop', 'tango', 'techno', 'trance',
#        'turkish', 'black-metal', 'death-metal', 'show-tunes', 'romance',
#        'emo', 'idm', 'iranian', 'trip-hop', 'deep-house',
#        'detroit-techno', 'grindcore', 'metalcore', 'breakbeat', 'happy',
#        'world-music', 'drum-and-bass'], dtype=object)

# %% [markdown]
# Check for duplicate values

# %%
df.shape
# Out:
# (3394589, 24)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (868789, 24)

# %% [markdown]
# There were a lot of duplicate values..

# %% [markdown]
# Check for null values

# %%
df.isna().any()
# Out:
# name                      False
# artists                   False
# album                     False
# release_date              False
# release_date_precision    False
# chart_power                True
# spotify_id                False
# uri                       False
# popularity                False
# danceability              False
# energy                    False
# key                       False
# loudness                  False
# mode                      False
# speechiness               False
# acousticness              False
# instrumentalness          False
# liveness                  False
# valence                   False
# tempo                     False
# duration_ms               False
# time_signature            False
# isrc                      False
# genres                    False
# dtype: bool

# %% [markdown]
# The null values for the Chart Power are valid, because not every song was in the Charts.

# %%
df.columns
# Out:
# Index(['name', 'artists', 'album', 'release_date', 'release_date_precision',
#        'chart_power', 'spotify_id', 'uri', 'popularity', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'isrc', 'genres'],
#       dtype='object')

# %% [markdown]
# ## Group by spotify id

# %% [markdown]
# First group the songs by the spotify id. This brings together all instances with different genres but same spotify id.

# %%
by_spotify_id = df.copy()
by_spotify_id = by_spotify_id.groupby('spotify_id').agg({
    'genres': list,
    'name': list,
    'artists': list,
    'album': list,
    'release_date': list,
    'release_date_precision': list,
    'uri': list,
    'isrc':list,
    'chart_power': list, 
    'popularity': list, 
    'danceability': list, 
    'energy': list,
    'key': list, 
    'loudness': list, 
    'mode': list, 
    'speechiness': list, 
    'acousticness': list, 
    'instrumentalness': list, 
    'liveness': list, 
    'valence': list,
    'tempo': list, 
    'duration_ms': list, 
    'time_signature': list
})

# %%
by_spotify_id.shape
# Out:
# (474676, 23)

# %%
by_spotify_id.columns
# Out:
# Index(['genres', 'name', 'artists', 'album', 'release_date',
#        'release_date_precision', 'uri', 'isrc', 'chart_power', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %% [markdown]
# Then reduce all categorical features such that there are no duplicated values in an instance for one feature.

# %%
by_spotify_id.head().T
# Out:
# spotify_id                                         000HmzbYBg0Uxe6cE47Tws  \
# genres                               [alt-rock, alternative, indie, rock]
# name                    [Exhuming McCarthy - Live, Exhuming McCarthy -...
# artists                                  [R.E.M., R.E.M., R.E.M., R.E.M.]
# album                   [Green (25th Anniversary Deluxe Edition), Gree...
# release_date             [1988-11-07, 1988-11-07, 1988-11-07, 1988-11-07]
# release_date_precision                               [day, day, day, day]
# uri                     [spotify:track:000HmzbYBg0Uxe6cE47Tws, spotify...
# isrc                    [USWB11301009, USWB11301009, USWB11301009, USW...
# chart_power                                          [nan, nan, nan, nan]
# popularity                                               [15, 15, 15, 15]
# danceability                                 [0.394, 0.394, 0.394, 0.394]
# energy                                       [0.968, 0.968, 0.968, 0.968]
# key                                                          [1, 1, 1, 1]
# loudness                                 [-3.698, -3.698, -3.698, -3.698]
# mode                                                         [1, 1, 1, 1]
# speechiness                                  [0.121, 0.121, 0.121, 0.121]
# acousticness                             [0.0113, 0.0113, 0.0113, 0.0113]
# instrumentalness                 [6.11e-05, 6.11e-05, 6.11e-05, 6.11e-05]
# liveness                                     [0.981, 0.981, 0.981, 0.981]
# valence                                              [0.8, 0.8, 0.8, 0.8]
# tempo                                [129.346, 129.346, 129.346, 129.346]
# duration_ms                              [193547, 193547, 193547, 193547]
# time_signature                                               [4, 4, 4, 4]
#
# spotify_id                              000KGSi8GylA9JmrcU6xtB  \
# genres                                              [hardcore]
# name                                        [Wake Up And Live]
# artists                                       [Youth Of Today]
# album                                        [Connecticut Fun]
# release_date                                            [1985]
# release_date_precision                                  [year]
# uri                     [spotify:track:000KGSi8GylA9JmrcU6xtB]
# isrc                                            [USA560674294]
# chart_power                                              [nan]
# popularity                                                 [0]
# danceability                                           [0.279]
# energy                                                 [0.917]
# key                                                        [1]
# loudness                                              [-8.624]
# mode                                                       [0]
# speechiness                                            [0.176]
# acousticness                                           [0.338]
# instrumentalness                                       [0.162]
# liveness                                               [0.301]
# valence                                                 [0.38]
# tempo                                                [107.281]
# duration_ms                                            [72387]
# time_signature                                             [4]
#
# spotify_id                                         000OJYYsNv9b3nSuVgnPfZ  \
# genres                                            [pop, rock, rockabilly]
# name                                    [Josephine, Josephine, Josephine]
# artists                 [Shakin' Stevens, Shakin' Stevens, Shakin' Ste...
# album                   [Give Me Your Heart Tonight, Give Me Your Hear...
# release_date                         [1982-10-04, 1982-10-04, 1982-10-04]
# release_date_precision                                    [day, day, day]
# uri                     [spotify:track:000OJYYsNv9b3nSuVgnPfZ, spotify...
# isrc                           [GBARL0801581, GBARL0801581, GBARL0801581]
# chart_power                                               [nan, nan, nan]
# popularity                                                   [18, 18, 18]
# danceability                                        [0.451, 0.451, 0.451]
# energy                                              [0.951, 0.951, 0.951]
# key                                                             [5, 5, 5]
# loudness                                         [-2.251, -2.251, -2.251]
# mode                                                            [1, 1, 1]
# speechiness                                      [0.0719, 0.0719, 0.0719]
# acousticness                                  [0.00745, 0.00745, 0.00745]
# instrumentalness                           [0.000159, 0.000159, 0.000159]
# liveness                                            [0.234, 0.234, 0.234]
# valence                                             [0.859, 0.859, 0.859]
# tempo                                            [174.11, 174.11, 174.11]
# duration_ms                                      [184360, 184360, 184360]
# time_signature                                                  [4, 4, 4]
#
# spotify_id                              000P83HDtOHcNVFZy7Q2Yu  \
# genres                                                 [salsa]
# name                                  [El Licor de Tu Boquita]
# artists                         [El Gran Combo De Puerto Rico]
# album                                                  [Unity]
# release_date                                            [1980]
# release_date_precision                                  [year]
# uri                     [spotify:track:000P83HDtOHcNVFZy7Q2Yu]
# isrc                                            [USMRE0801806]
# chart_power                                              [nan]
# popularity                                                [21]
# danceability                                           [0.619]
# energy                                                 [0.561]
# key                                                        [7]
# loudness                                              [-8.377]
# mode                                                       [0]
# speechiness                                           [0.0736]
# acousticness                                           [0.438]
# instrumentalness                                    [4.17e-05]
# liveness                                               [0.126]
# valence                                                [0.696]
# tempo                                                  [88.94]
# duration_ms                                           [242493]
# time_signature                                             [4]
#
# spotify_id                              000QVWRKGiK8oOGfCjrHuY
# genres                                                  [folk]
# name                       [Dil Wich Kide Chhupa Ke Rakh Laan]
# artists                          [Sardool Sikander,Amar Noori]
# album                               [Gora Rang Deyin Na Rabba]
# release_date                                      [1989-02-02]
# release_date_precision                                   [day]
# uri                     [spotify:track:000QVWRKGiK8oOGfCjrHuY]
# isrc                                            [INS188910383]
# chart_power                                              [nan]
# popularity                                                 [6]
# danceability                                           [0.697]
# energy                                                 [0.602]
# key                                                        [5]
# loudness                                              [-7.435]
# mode                                                       [1]
# speechiness                                           [0.0725]
# acousticness                                           [0.705]
# instrumentalness                                         [0.0]
# liveness                                               [0.199]
# valence                                                [0.833]
# tempo                                                  [86.47]
# duration_ms                                           [364000]
# time_signature                                             [4]

# %%
def get_release_year_index(release_dates):
    '''
    Returns the index of the release year.

    Parameter
    ---------
    release_dates: List
        List that contains all dates a version of the song was released.

    Return
    ------
    min_index: number
        Index in the list that contains the oldest release year.
    '''
    release_year = []
    for date in release_dates:
        release_year.append(int(date[:4]))
    return (np.array(release_year)).argmin()

# %%
def select_oldest_song_old(df, isrc_flag=False):
    features = ['artists', 'album', 'release_date_precision', 'uri', 'release_date', 'chart_power', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'name']

    if isrc_flag:
        features.append('genres')
        features.append('spotify_id')
    else:
        features.append('isrc')
    df_copy = df.copy()
    for index, instance in df_copy.iterrows():
        if type(instance['release_date']) == list:
            #min_index = get_release_year_index(instance['release_date'])
            release_year = []
            for date in instance['release_date']:
                release_year.append(int(date[:4]))
            min_index = (np.array(release_year)).argmin()
            for feature in features:
                if type(instance[feature] == list):
                    df_copy.loc[index, feature] = instance[feature][min_index]
    return df_copy

# %%
def select_oldest_song(df, isrc_flag=False):
    features = [
        'artists', 'album', 'release_date_precision', 'uri', 'release_date',
        'chart_power', 'popularity', 'danceability', 'energy', 'key', 'loudness',
        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
        'valence', 'tempo', 'duration_ms', 'time_signature', 'name'
    ]

    if isrc_flag:
        features.extend(['genres', 'spotify_id'])
    else:
        features.append('isrc')

    df_copy = df.copy()

    for index, instance in df_copy.iterrows():
        if isinstance(instance['release_date'], list):
            release_years = [int(date[:4]) for date in instance['release_date']]
            min_index = np.argmin(release_years)

            for feature in features:
                if isinstance(instance[feature], list):
                    df_copy.loc[index, feature] = instance[feature][min_index]

    return df_copy

# %%
by_spotify_id = select_oldest_song(by_spotify_id)

# %%
by_spotify_id.shape
# Out:
# (474676, 23)

# %%
by_spotify_id.to_csv("data/by_spotify_id.csv")

# %% [markdown]
# ## Group by isrc

# %% [markdown]
# The next step is to group all the songs by the isrc number since this should be the unique identifier.

# %%
by_isrc = by_spotify_id.copy()
by_isrc.reset_index(inplace=True)
by_isrc = by_isrc.groupby('isrc').agg({
    'genres': list,
    'name': list,
    'artists': list,
    'album': list, 
    'release_date': list,
    'release_date_precision': list,
    'uri': list,
    'spotify_id':list,
    'chart_power': list, 
    'popularity': list, 
    'danceability': list, 
    'energy': list,
    'key': list, 
    'loudness': list, 
    'mode': list, 
    'speechiness': list, 
    'acousticness': list, 
    'instrumentalness': list, 
    'liveness': list, 
    'valence': list,
    'tempo': list, 
    'duration_ms': list, 
    'time_signature': list
})

# %%
by_isrc.head().T
# Out:
# isrc                                              AEA040700577  \
# genres                                    [[j-pop, jazz, pop]]
# name                                           [Bala Wala Chi]
# artists                                         [Ziad Rahbani]
# album                                           [Houdou Nisbi]
# release_date                                      [1985-01-01]
# release_date_precision                                   [day]
# uri                     [spotify:track:0fylgLeNObjVvwhd8caHqX]
# spotify_id                            [0fylgLeNObjVvwhd8caHqX]
# chart_power                                              [nan]
# popularity                                                [41]
# danceability                                           [0.291]
# energy                                                 [0.231]
# key                                                        [9]
# loudness                                             [-18.808]
# mode                                                       [1]
# speechiness                                           [0.0418]
# acousticness                                           [0.952]
# instrumentalness                                       [0.382]
# liveness                                               [0.237]
# valence                                                [0.371]
# tempo                                                [157.168]
# duration_ms                                           [207560]
# time_signature                                             [3]
#
# isrc                                              AEA040700578  \
# genres                            [[groove, j-pop, jazz, pop]]
# name                                            [Houdou Nisbi]
# artists                                         [Ziad Rahbani]
# album                                           [Houdou Nisbi]
# release_date                                      [1985-01-01]
# release_date_precision                                   [day]
# uri                     [spotify:track:0yMFpBNCYXqwwOAg23bC8a]
# spotify_id                            [0yMFpBNCYXqwwOAg23bC8a]
# chart_power                                              [nan]
# popularity                                                [31]
# danceability                                           [0.587]
# energy                                                 [0.184]
# key                                                        [7]
# loudness                                             [-18.954]
# mode                                                       [0]
# speechiness                                           [0.0308]
# acousticness                                           [0.814]
# instrumentalness                                       [0.951]
# liveness                                              [0.0827]
# valence                                                [0.495]
# tempo                                                [128.386]
# duration_ms                                           [272240]
# time_signature                                             [3]
#
# isrc                                              AEA040700579  \
# genres                            [[groove, j-pop, jazz, pop]]
# name                                        [Nafs Al Sheghlat]
# artists                                         [Ziad Rahbani]
# album                                           [Houdou Nisbi]
# release_date                                      [1985-01-01]
# release_date_precision                                   [day]
# uri                     [spotify:track:6G8l1kI8QlTD0UDIak5F8H]
# spotify_id                            [6G8l1kI8QlTD0UDIak5F8H]
# chart_power                                              [nan]
# popularity                                                [21]
# danceability                                           [0.496]
# energy                                                 [0.264]
# key                                                        [3]
# loudness                                             [-21.179]
# mode                                                       [1]
# speechiness                                           [0.0449]
# acousticness                                           [0.954]
# instrumentalness                                       [0.887]
# liveness                                               [0.271]
# valence                                                [0.304]
# tempo                                                  [82.63]
# duration_ms                                           [160093]
# time_signature                                             [4]
#
# isrc                                              AEA040700580  \
# genres                            [[groove, j-pop, jazz, pop]]
# name                                      [Yalla Kichou Barra]
# artists                                         [Ziad Rahbani]
# album                                           [Houdou Nisbi]
# release_date                                      [1985-01-01]
# release_date_precision                                   [day]
# uri                     [spotify:track:21g76Lq5Jg4QvfTDvi4PlH]
# spotify_id                            [21g76Lq5Jg4QvfTDvi4PlH]
# chart_power                                              [nan]
# popularity                                                [17]
# danceability                                           [0.676]
# energy                                                  [0.43]
# key                                                        [5]
# loudness                                             [-18.456]
# mode                                                       [1]
# speechiness                                           [0.0341]
# acousticness                                            [0.43]
# instrumentalness                                       [0.838]
# liveness                                               [0.124]
# valence                                                [0.656]
# tempo                                                [102.485]
# duration_ms                                           [155667]
# time_signature                                             [4]
#
# isrc                                              AEA040700581
# genres                       [[groove, j-pop, jazz, pop, pop]]
# name                                                 [Ma Tfel]
# artists                                         [Ziad Rahbani]
# album                                           [Houdou Nisbi]
# release_date                                      [1985-01-01]
# release_date_precision                                   [day]
# uri                     [spotify:track:0pKxrkFh8fxPKpkO29MYmi]
# spotify_id                            [0pKxrkFh8fxPKpkO29MYmi]
# chart_power                                              [nan]
# popularity                                                [31]
# danceability                                           [0.474]
# energy                                                 [0.428]
# key                                                        [5]
# loudness                                             [-18.178]
# mode                                                       [0]
# speechiness                                           [0.0436]
# acousticness                                           [0.749]
# instrumentalness                                       [0.941]
# liveness                                               [0.115]
# valence                                                [0.752]
# tempo                                                [150.656]
# duration_ms                                           [265173]
# time_signature                                             [4]

# %%
by_isrc = select_oldest_song(by_isrc, True)

# %%
by_isrc.isna().any()
# Out:
# genres                    False
# name                      False
# artists                   False
# album                     False
# release_date              False
# release_date_precision    False
# uri                       False
# spotify_id                False
# chart_power                True
# popularity                False
# danceability              False
# energy                    False
# key                       False
# loudness                  False
# mode                      False
# speechiness               False
# acousticness              False
# instrumentalness          False
# liveness                  False
# valence                   False
# tempo                     False
# duration_ms               False
# time_signature            False
# dtype: bool

# %%
by_isrc.head().T
# Out:
# isrc                                            AEA040700577  \
# genres                                    [j-pop, jazz, pop]
# name                                           Bala Wala Chi
# artists                                         Ziad Rahbani
# album                                           Houdou Nisbi
# release_date                                      1985-01-01
# release_date_precision                                   day
# uri                     spotify:track:0fylgLeNObjVvwhd8caHqX
# spotify_id                            0fylgLeNObjVvwhd8caHqX
# chart_power                                              NaN
# popularity                                                41
# danceability                                           0.291
# energy                                                 0.231
# key                                                        9
# loudness                                             -18.808
# mode                                                       1
# speechiness                                           0.0418
# acousticness                                           0.952
# instrumentalness                                       0.382
# liveness                                               0.237
# valence                                                0.371
# tempo                                                157.168
# duration_ms                                           207560
# time_signature                                             3
#
# isrc                                            AEA040700578  \
# genres                            [groove, j-pop, jazz, pop]
# name                                            Houdou Nisbi
# artists                                         Ziad Rahbani
# album                                           Houdou Nisbi
# release_date                                      1985-01-01
# release_date_precision                                   day
# uri                     spotify:track:0yMFpBNCYXqwwOAg23bC8a
# spotify_id                            0yMFpBNCYXqwwOAg23bC8a
# chart_power                                              NaN
# popularity                                                31
# danceability                                           0.587
# energy                                                 0.184
# key                                                        7
# loudness                                             -18.954
# mode                                                       0
# speechiness                                           0.0308
# acousticness                                           0.814
# instrumentalness                                       0.951
# liveness                                              0.0827
# valence                                                0.495
# tempo                                                128.386
# duration_ms                                           272240
# time_signature                                             3
#
# isrc                                            AEA040700579  \
# genres                            [groove, j-pop, jazz, pop]
# name                                        Nafs Al Sheghlat
# artists                                         Ziad Rahbani
# album                                           Houdou Nisbi
# release_date                                      1985-01-01
# release_date_precision                                   day
# uri                     spotify:track:6G8l1kI8QlTD0UDIak5F8H
# spotify_id                            6G8l1kI8QlTD0UDIak5F8H
# chart_power                                              NaN
# popularity                                                21
# danceability                                           0.496
# energy                                                 0.264
# key                                                        3
# loudness                                             -21.179
# mode                                                       1
# speechiness                                           0.0449
# acousticness                                           0.954
# instrumentalness                                       0.887
# liveness                                               0.271
# valence                                                0.304
# tempo                                                  82.63
# duration_ms                                           160093
# time_signature                                             4
#
# isrc                                            AEA040700580  \
# genres                            [groove, j-pop, jazz, pop]
# name                                      Yalla Kichou Barra
# artists                                         Ziad Rahbani
# album                                           Houdou Nisbi
# release_date                                      1985-01-01
# release_date_precision                                   day
# uri                     spotify:track:21g76Lq5Jg4QvfTDvi4PlH
# spotify_id                            21g76Lq5Jg4QvfTDvi4PlH
# chart_power                                              NaN
# popularity                                                17
# danceability                                           0.676
# energy                                                  0.43
# key                                                        5
# loudness                                             -18.456
# mode                                                       1
# speechiness                                           0.0341
# acousticness                                            0.43
# instrumentalness                                       0.838
# liveness                                               0.124
# valence                                                0.656
# tempo                                                102.485
# duration_ms                                           155667
# time_signature                                             4
#
# isrc                                            AEA040700581
# genres                       [groove, j-pop, jazz, pop, pop]
# name                                                 Ma Tfel
# artists                                         Ziad Rahbani
# album                                           Houdou Nisbi
# release_date                                      1985-01-01
# release_date_precision                                   day
# uri                     spotify:track:0pKxrkFh8fxPKpkO29MYmi
# spotify_id                            0pKxrkFh8fxPKpkO29MYmi
# chart_power                                              NaN
# popularity                                                31
# danceability                                           0.474
# energy                                                 0.428
# key                                                        5
# loudness                                             -18.178
# mode                                                       0
# speechiness                                           0.0436
# acousticness                                           0.749
# instrumentalness                                       0.941
# liveness                                               0.115
# valence                                                0.752
# tempo                                                150.656
# duration_ms                                           265173
# time_signature                                             4

# %% [markdown]
# Create a new feature year that contains only the year.

# %%
by_isrc['year'] = by_isrc['release_date'].apply(lambda x: int(x[:4]))

# %%
by_isrc['year'].unique()
# Out:
# array([1985, 1989, 1984, 1987, 1986, 1988, 1982, 1983, 1980, 1981, 2023])

# %%
(by_isrc['year'] > 1990).sum()
# Out:
# 7

# %% [markdown]
# Remove all songs that are not from the 80s

# %%
smaller = list(by_isrc['year'] < 1980) 
larger = list(by_isrc['year'] > 1989)
remove_index = by_isrc[[x or y for x, y in zip(smaller, larger)]].index
print(remove_index)
print(by_isrc.shape)
by_isrc.drop(index=remove_index, inplace=True)
print(by_isrc.shape)
# Out:
# Index(['DER412202108', 'DER412202109', 'DER412202110', 'DER412202111',
#        'DER412202112', 'DER412202113', 'DER412202114'],
#       dtype='object', name='isrc')
# (428362, 24)
# (428355, 24)

# %%
by_isrc.release_date_precision = by_isrc.release_date_precision.astype(str)

# %% [markdown]
# Convert song and artists names to lowercase

# %%
by_isrc['name'] = by_isrc['name'].str.lower()
by_isrc['artists'] = by_isrc['artists'].str.lower()

# %%
by_isrc.drop_duplicates(['name','artists'], inplace=True)

# %%
by_isrc.shape
# Out:
# (416154, 24)

# %%
by_isrc.isna().any()
# Out:
# genres                    False
# name                      False
# artists                   False
# album                     False
# release_date              False
# release_date_precision    False
# uri                       False
# spotify_id                False
# chart_power                True
# popularity                False
# danceability              False
# energy                    False
# key                       False
# loudness                  False
# mode                      False
# speechiness               False
# acousticness              False
# instrumentalness          False
# liveness                  False
# valence                   False
# tempo                     False
# duration_ms               False
# time_signature            False
# year                      False
# dtype: bool

# %%
by_isrc.to_csv('data/by_isrc.csv')
